# %%
import pandas as pd

df = pd.read_csv('Crawling_KPK_Tweet.csv', encoding='ISO-8859-1')
df.head()
# Out:
#                IdTweet               IdUser                  UserName  \
# 0  1471322989568299008  1410229937290637312                 Fachrezzy
# 1  1471322987999555585            790616377                   Hellboy
# 2  1471322987261349888  1058255746482098176                  Mugi.com
# 3  1471322892738519043  1440106084845318145                 Alejandro
# 4  1471322880159805440  1402234579985989632  `â¢.^masâ«WAHAÎ².^â¢`
#
#         ScreenName                     Location                    TweetAt  \
# 0      fachrezzy_s  Dibawah Lindungan Allah swt  2021-12-16 03:35:11+00:00
# 1        delliAmin                          NaN  2021-12-16 03:35:10+00:00
# 2    Mujiyono_1926       Purbalingga, Indonesia  2021-12-16 03:35:10+00:00
# 3  Alejandro170776                          NaN  2021-12-16 03:34:48+00:00
# 4  WahabWahabbb911         NEGARA KESATUAN RI.   2021-12-16 03:34:45+00:00
#
#            UploadTweet                                      OriginalTweet
# ...
